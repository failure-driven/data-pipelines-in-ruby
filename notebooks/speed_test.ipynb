# %% [markdown]
# # Speed test

# %%
import psycopg2
import pprint
import pandas as pd
import pyarrow as pa
import pyarrow.csv as csv

# %% [markdown]
# ## Postgres to Python

# %%
# %%time

conn = psycopg2.connect("postgres://:@localhost:5432/ruby_pipeline_demo_development")
cursor = conn.cursor()
get_yellow_tripdata_sql = """
    SELECT
        *
    FROM
        yellow_tripdata;
"""
yellow_tripdata_df = pd.read_sql(get_yellow_tripdata_sql, conn)
conn.close()

yellow_tripdata_df
# Out:
# CPU times: user 19.6 s, sys: 19.2 s, total: 38.8 s
# Wall time: 55 s
#               id  vendorid tpep_pickup_datetime tpep_dropoff_datetime  \
# 0              1       1.0  2020-01-01 00:28:15   2020-01-01 00:33:03
# 1              2       1.0  2020-01-01 00:35:39   2020-01-01 00:43:04
# 2              3       1.0  2020-01-01 00:47:41   2020-01-01 00:53:52
# 3              4       1.0  2020-01-01 00:55:23   2020-01-01 01:00:14
# 4              5       2.0  2020-01-01 00:01:58   2020-01-01 00:04:16
# ...          ...       ...                  ...                   ...
# 6405003  6405004       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00
# 6405004  6405005       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00
# 6405005  6405006       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57
# 6405006  6405007       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32
# 6405007  6405008       NaN  2020-01-31 22:44:00   2020-01-31 23:06:00
#
# ...

# %% [markdown]
# ## Pandas

# %%
# %%time
df = pd.read_csv(
    "../data/nyc_yellow_tripdata/yellow_tripdata_2020-01.csv"
)
df
# Out:
# /Users/michael/miniforge3/lib/python3.9/site-packages/IPython/core/magics/execution.py:1321: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# CPU times: user 5.04 s, sys: 1.12 s, total: 6.16 s
# Wall time: 6.87 s
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# ...

# %% [markdown]
# ## PyArrow

# %%
# %%time
table = csv.read_csv(
    "../data/nyc_yellow_tripdata/yellow_tripdata_2020-01.csv"
)
adf = table.to_pandas()
adf
# Out:
# CPU times: user 3.45 s, sys: 1.41 s, total: 4.86 s
# Wall time: 1.34 s
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2020-01-01 00:28:15   2020-01-01 00:33:03              1.0
# 1             1.0  2020-01-01 00:35:39   2020-01-01 00:43:04              1.0
# 2             1.0  2020-01-01 00:47:41   2020-01-01 00:53:52              1.0
# 3             1.0  2020-01-01 00:55:23   2020-01-01 01:00:14              1.0
# 4             2.0  2020-01-01 00:01:58   2020-01-01 00:04:16              1.0
# ...           ...                  ...                   ...              ...
# 6405003       NaN  2020-01-31 22:51:00   2020-01-31 23:22:00              NaN
# 6405004       NaN  2020-01-31 22:10:00   2020-01-31 23:26:00              NaN
# 6405005       NaN  2020-01-31 22:50:07   2020-01-31 23:17:57              NaN
# 6405006       NaN  2020-01-31 22:25:53   2020-01-31 22:48:32              NaN
# ...
